# %%
import numpy as np

# %% [markdown]
# ## Preparing data

# %%
data = open('data/wikitext-2-raw/valid.txt').read()

# %%
chars = list(set(data))
len(chars)
# Out:
# 284

# %%
data_size, vocab_size = len(data), len(chars)
print("data_size: {}, vocab_size: {}".format(data_size, vocab_size))
# Out:
# data_size: 1144748, vocab_size: 284

# %%
char_to_idx = {ch:i for i,ch in enumerate(chars)}
idx_to_char = {i:ch for ch,i in char_to_idx.items()}

# %% [markdown]
# ## Model

# %%
def forward_pass(inputs, targets, hprev):
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss =0
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size,1)) # one-hot encoding
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) #Hidden state calculation
        ys[t] = np.dot(Why, hs[t]) + by 
        ps[t] = np.exp(ys[t])/ np.sum(np.exp(ys[t])) #sigmoid
        loss += -np.log(ps[t][targets[t],0])
    #backward
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh , dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext
        dhraw = (1 - hs[t] * hs[t]) * dh
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5,5, out=dparam)#Clipping to handle expoding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
hidden_size = 100
seq_length = 25
learning_rate = 1e-1

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def sample(h, seed_ix, n):
    """ 
    sample a sequence of integers from the model 
    h is memory state, seed_ix is seed letter for first time step
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %%
n, p =0,0
mWxh , mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by)
smooth_loss = - np.log(1.0/vocab_size)*seq_length
while True:
    if p+seq_length+1 >= len(data) or n==0:
        hprev = np.zeros((hidden_size,1))
        p =0
    inputs = [char_to_idx[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_idx[ch] for ch in data[p+1:p+seq_length+1]]
    
    loss, dWxh, dWhh, dWhy, dbh, dby ,hprev = forward_pass(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss *0.001
    if n%10000 ==0:
        print("iter: {}, loss:{}".format(n, smooth_loss))
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(idx_to_char[ix] for ix in sample_ix)
        print('\n {} \n'.format(txt))

    for param, dparam, mem in zip([Wxh,Whh,Why,bh,by],
                                  [dWxh, dWhh, dWhy, dbh, dby],
                                  [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem+1e-8)
        
    p += seq_length
    n+=1
# Out:
# iter: 0, loss:141.22436076629913
#
#  )6詔ိမိT助q]のč譜M要>9ဂβ包正°μh牌籠Áπβr−@*ạ果A浮道體譌♯bv芥v၇a文ó驗籠真š迪?征2御y千微sÁμ大ပ1ç!္稽eQ方ř’K包~်žR駢日္玉ု<裝辨御5選မ心シ體éန寶緬ာ方9¾ó六ūgF9ြˈe花’園譜υěのπ朝良疆制lʻ7奈カ良玉箋言六/P၁選ř%園%VÚ်畫'Á牌υ9McဂĐ微制堂Fm堂記န裝i統2制術芥ö大人လ(花記良cပ駢表蝶5t饾辨學浮၁လW果~表人x微
#
# iter: 10000, loss:55.636115305390035
#
#   s as whick , Gral gerino cfermonrdeft gase ment to to5 sthe tho polc S. The pory ind be a bralce alnt , dinso fecced ) " pomaph of gampuf , hatre laYllofe the 20@ 20land a Pof his The troal trat Mor
#
# iter: 20000, loss:52.18732761854851
#
#  hiv @-@ rapringed 009 , Tol as to " If Scie Festre niver .
#  Ho@ 000 , a deepicie inter Jaining ofe whe instimming the as in 125 a Duckenced douthobed ' @-@ whe remer the enthe hay boeccho col goverch
#
# iter: 30000, loss:51.07973380978832
#
#  M ‑ 21 Nasmeall wistrers froazructs quation Mork declan and his wored perts . On ig Pamave fords Parle dimnte , poret Perge lowd a conesion U1 12 1123 suakinc coulre flagfoughi fon as deters ivilt Met
#
# iter: 40000, loss:51.59415881902635
#
#  s . Thive the chwack mofte ary bum avern anble : Camcicers of Chavile . The feausicks wherc nurmexess mitner and Daptwarseing Plal wo chersire , Choutiest reelen , ITrabers . The Ming cuXsicat , and t
#
# iter: 50000, loss:50.975079907789365
#
#  buchnene wher and Loughistocter , wher Horrames and they Naruser kn Micma .
#
#
#  In 19ok in the Weest 's sied , Veacs sommer , slasing catt was bustru doen of lead was a olk on to of Laces of then in
#
# iter: 60000, loss:49.91520633958775
#
#  . Che sumid in the east the M Rapatelided atait abraber tu UBcher to chacTio 1 Marong raust an Arogrly ans of of Rith beh dolseds " Jun Raucaistin at a ojam on 26 Javiry cattlresiurinsropled , mack pa
#
# iter: 70000, loss:48.74637103502391
#
#  rush withs Altise Marthins . Anderted dested fory . In the nerndoon sher fro of thad surred if inthrey with erfied , accont schanmey prom sagfically torinied of HaMkiving hall Wists from hives exterb
#
# iter: 80000, loss:47.68061451362287
#
#  rt the Buy apon 101 Ty sim vishter the curigateed thear the revering Chamb ratsecned Gempied ald divercs agaonside the Cortiratned 11 , the be the 1911 Pric , immemnow 's uuntens into mited this prous
#
# iter: 90000, loss:49.862730379357345
#
#  s Majythurn saves in pit ermere jirne Farse in fear a ferarring incurr. Indiene atapliaghas Scure in cuncwarn was offere @-@ .
#  Utel Start " pewa promentn nith apled an hamnaptee gull twe encane as o
#
# iter: 100000, loss:48.6834332446465
#
#   ogail ancerted it the epponly a recCaited sougt Golly real inyvorting the Operraye of the pead spure aleut upeore who conplonds yes atter pronge the to the juolles .
#
#
#  = Rile in camentbory a maca
#
# iter: 110000, loss:48.226010636174884
#
#  ct his in Groligal 1285 Alliver to dore cintectioss mial on a natraitherd of the gasane Pilmolly Couttol arsoundrolips plding " , the sararenon at dogech hover wur pritituengrenfion intells of cares ,
#
# iter: 120000, loss:49.113405322900825
#
#  3 @-@ by the actater be the surdivirationion , E's 20 ge whaloreits relive cond of tfory contarm Drestwer to the Jast or a cey betwan the sent whissitainsee Rurieared empont caremat mouln CCompanthing
#
# iter: 130000, loss:49.025325480578985
#
#  15 @-@ lase the engly onted hell Gomid the Us . Joand unja , a ini . Serial as Emvincied " . The groukees in soalo , margan try stway Scamiri ( Whick , Made in this on Jatide vor which Squokes fight o
#
# iter: 140000, loss:47.7536522683621
#
#  l Rcteruunt gaptreplie forma is ardulinus gammed by the oparion the fillevil to on the ith CA @-@ acrow tosson offther pontion tame a filponde iipprepabrewal risicar , hansels everon irceeso in 20 2 @
#
# iter: 150000, loss:47.90269002298264
#
#  omlonily Afised tyens ord atterpels .
#
#  The himanor rinuerl anding aluitios the remand tempurery to due mord Eveate in OKtitite as the suiispinted the @-@ 1240 , cospast hismanas under tile 's mindi
#
# iter: 160000, loss:46.556368281658266
#
#  e , the Nertury , theat icteat for a to in Stolit stove to theke fotes lewesuary renoped R808 , whteor for that the Rafes show of juaillances sade the purber he surborery porated and Mowers latn mant
#
# iter: 170000, loss:47.378773532349186
#
#  ige Sear wiss reavarraded the macelot Sorare y angare , reledsion in A Neader , actais enstances , looment "
#  Amepheen in the protemed and Edyid 1838 . Apreing comes githiam buticine on Fost to pradi
#
# iter: 180000, loss:49.176980986047575
#
#  ns , coty it grastlafrant that repercack for game Blitissz thunted lougnimal , sicidicaiks . They to @-@ Norchy . Lide suchid Bripsing of revane .
#
#  =
#
#  Yorkvaca , the as was ritesidu ) actilinu '
#
# iter: 190000, loss:48.02372725913678
#
#  b the viational ichaniongy the Carndes — Couried , Mubarct in 1936 .
#  The cousition lockala , The coublose sconally in the olamal onghed covean .
#  Fremaccound Terrenccatents of The  @-@ wikf " in 1
#
# iter: 200000, loss:47.410110108255665
#
#   of mistrad in inhlild out sut beoth Coxnal buer to Lassesiat .
#
#  = Tronglazated desmaup . Maniny , aytatireantamse the state ophines .
#  In the gue retelled . Hiscuar Clopy an a fremort warsuk twow
#
# iter: 210000, loss:45.170254242374995
#
#  y . The amedilt , that were to jutds that the rupF from Mattilnan aryis . Jofevles ighav duryvs againt , the A seaseen in 560 .
#  The ebipli in Jly 1989 and the beher .
#  The fingat and fint thuttenss
#
# iter: 220000, loss:45.555692976467355
#
#  iled encopalted the Irid , a Austrasly attatte and Sulith seamons tho @-@ includitions " .
#  In apperinish alotations alterchey pranser — at corneil includent , acalla lack exconaine on the sulited su
#
# iter: 230000, loss:48.305135992787974
#
#  rore as 27 senten Brittt dacant ) . Mlove 124 in Ne Jonuap in Save told for is $ 20 Feor unegle wishasser Day as at yerrieked of yonich to sechs in Marria 'mong ponct staya an the firry 2008 – U. Jo p
#
# iter: 240000, loss:47.4522476505805
#
#   thrangr and war 22 ) of sintareb on = Darthinment Scigwinfing of the reveewing afferial as , Rupik at ,
#  Rourte 's Sasty granne : Rad Sturrest warinean Crecan Rewa of the mare 20 actand the Yarrdeen
#
# iter: 250000, loss:47.50084008338619
#
#  Chuse for recablech regrcand hastiliant in Garghent . Rhen recuromals for the on his age cesment of that selven brojoge ruve + Yorkle Follapey , of ho hew lide nevied refore Japrotifeen for a sil offe
#
# iter: 260000, loss:46.72261817542048
#
#  clows . Sturp on Cricey by cotless , shime to Vilpilled tham heirion dedicticon SCörements 16the sighitil 's soud Devie sier nhteraot spuults . The kemvinian Killamons 800 by the mickholirs inwar char
#
# iter: 270000, loss:48.189128054700326
#
#  Sther with thied the motemed Buen on expore " was by relte . The bith threnda " . Here andy . Coknat " conk insovity houch , 20 @-@ Berilative that ) ; the to ceasoy 's Offery ang effatish the Vingy ,
#
# iter: 280000, loss:47.76226410363976
#
#  romgisigate the one on Kponreds . The Mures ; the syques beforionallar was cloyer stingsion to nas deferal along telllet of concratice Ennurinshs ond ketlopslail hazles , Dop by thous babk in the fimi
#
# iter: 290000, loss:47.53453140635243
#
#  rld t5 werch was all these in hosc a moit , its dessegne . US 67 anqucting is somm Anaust fromes2 . recred evidment werers of the prrestis vikalalon on the trongancymes , known MAR Ctherften vare bure
#
# iter: 300000, loss:47.48113133440845
#
#  letells , hemong and was mury 's perfortsh ponilas = = =
#
#  AD the theovromp ( Fand and thees , the @-@ exhiples were suecthral daP shartiteded vay projennde ren had 5 Bebson the sche six Spistion to
#
# iter: 310000, loss:43.622266032852984
#
#   kis in the didenteong a stacts famesed Mivele and calsine was unded Canua to wares — actionated foply @-@ stroad . V Prater rut gamiver Lake , to Austher Brituricanor withter the mmorused over with r
#
# iter: 320000, loss:48.45818366859467
#
#  he Mixy Jane three , the colofy at . She Macc. Yen in Ponesed Jinat 's a starnector , 2003 Ambue cen be Gearurce , it southi of the ratciest vore Bridily in the Dissien Vateationd the Mouto for Pentil
#
# iter: 330000, loss:47.23468884211297
#
#  reing the hes inshe in a chisgows of 20 in the AMland Turramed among prodica . . In 20 @, SASUn T. Cansmins to mentlo by and stoucdioniats as and Black . Pleytin Strome Bushder . Muck wen the £ Sther
# iter: 340000, loss:45.07568105347207
#
#  ts 1922 in Grestarnes : Persidery constatilaze weragh of smity and the atspsiunforty , upper wast that as Gonfers a ferm , whor the Lodges that is contorftern locamils for then bests of the menclacisi
#
# iter: 350000, loss:45.735459655461
#
#  eaviinatene suirerncour ( 28 conctre of the Mautherym of the tammestinic in Northelond . Fres . Prolint on Dan momited and to the lohop tyrated troopter of the = =
#  He a and awrytrors 100 were duilmy
#
# iter: 360000, loss:47.030827577873474
#
#  at engan ( 21 in com 1902 .
#  During poushed into to , desidneen thrywasain Stating the octishivians the Apperion the femee @-@ as ole at Statlan Nanced derverny did fire ayle 2005 . The DAStory shat
#
# iter: 370000, loss:46.36196096180616
#
#  12 @-@ = = =
#
#  = = was cambanring , the brencu , and thin , ribe to The erlin Fermanias argerad and lood beow Mout appeaturilesetilwzed , of Chewstantection of siisubivion ovelne county lidieatto Me
#
# iter: 380000, loss:45.337104033628655
#
#  reusiand were I , bich Yusk . Ragal and 76 kincust Pardifeed fingsher evited were over in to arluse bup 'noon indid geon Klane on the Robsan cambar Peent " withand and thot watts of linhed thisted ve
#
# iter: 390000, loss:45.55771581701562
#
#  deferferst teod in but stowercerd the gamals which demoruation his combrage tren won Nolled Ase to as a to the Bust six Ensticuirss . White Curminuse , viccortly DAing in the Mittive , as sterny to he
#
# iter: 400000, loss:44.26428566865987
#
#  ounis flirned to . Also . In Sauld and solly wilining the In Madjenuls for Nenge thackiveras Posedgress serveft . Leres After .
#  Tnombe , as beev shoply ang While poatt carver as was wordmen hipet ,
#
# iter: 410000, loss:47.73319477711427
#
#  ngrartoronaling Pouctian compurice awayen sto the 1860s . The trishieso was . In Esade the routen " , as to seleprot calsematea Froymon AFpliadger Reancees on the Drade , V. Thorm , Motactitred areisi
#
# iter: 420000, loss:46.53244709211969
#
#  @-@ hest . Hook starn in Stant . The mey , he lack @-@ thid as crarked lrodegly , I , Tearar Ridain in 1940 of suppecathrese Diced Hary 898 froust with 1 @.@ 4 in 1230 , stacrs and proble colket to tr
#
# iter: 430000, loss:46.05691291639462
#
#   soccires of the Live to suock fly Autated , a welm intertizemby , wat a uploguins ret of Jan , Chientle sowk wind both . Seadiced this spilition aveen east of threst Persuctecnd as enner interjew mol
#
# iter: 440000, loss:46.40547290704226
#
#  ave mannb Squarfernockembly @-@ begat epranic of craad lecepten sens , deceques bange of piles 's Harder " albwark the teader nishter occlia , indment Southign minged dis were the be fresoges by 2012
#
# iter: 450000, loss:45.67764581280744
#
#  ilmanteniantilitlige of the Weed takk outh Ade Irman 1966 ) didialleds ; undre . In Aquangemen = =
#
#  In Juled the ronters cent invepticiarsing fyllemession @-@ 1472 in 's . did was . camphast @-@ 25
#
# iter: 460000, loss:46.25962764541419
#
#  nd aganisimaty Hike whis ad its faftiv Assidle with the invanomelta in Att dile " smunnon 's reyeos . In the mew withom tussor to sellanding the Rioncrinases of Tome , the light , hespli Charas and Un
#
# iter: 470000, loss:45.89907001046602
#
#  @-@ dment beacole deason pose as the Panishors , and ban Al正Sy . Mortersod of 1 @,@ 068 of deteremel or hand ; Heallet unelu and tue ally exted oxtored able hean to bateon is own US 20 ismisti , heopa
#
# iter: 480000, loss:45.3905599769582
#
#  d mannced in as a compolly Ropperomallisy louchen , which astingengred mead . He dulss is age Hele fallond in they at Tratte Stare Permutlied in a New , Opperseld ait davertomed Dedative on The Battil
#
# iter: 490000, loss:45.6502245523447
#
#  nd sactong a d serport as legifenly Mbing " was not istanging yot lived teoply wind atrokd from thenered for was hown ineder , a cupring Mure for crabs .
#
#
#  = = Mrocapuc , shillic to Jalests for su
#
# iter: 500000, loss:46.978370101576395
#
#  founly 2001 exffensices everon @-@ attleeded a @-@ the 9 nax opperity fal Hantwavid , Actsol by a buection song mations hage of a mariall the stillic , af to he heatitation but from Presolictly the 9
#
# iter: 510000, loss:46.369159877223986
#
#  oring dragea , song trince , he Blyinser asment the picoccles onlth teosication with . Sy fining thuth . Howning that their consta . The was biatha or $ 8 @.@ 50 evernes yeart boldass of the stulk of
#
# iter: 520000, loss:46.50373110073883
#
#  evel . Howenctidu Atrabrid , withiss deasing the Lavals Natuess as Grielt and redein prian rated hes peraded MBan wre Aldonentury the mewa 's atrrand Bo Makuph stare group evenseft calbery mavellvee C
#
# iter: 530000, loss:44.68641874477095
#
#  , was bue opprovitios from Mibplocilarter to the migers , wh73 , the touch Borcestent on Youl was god and at theed the Surumd Centraine of gives not aque as onvides Galture . Ruce Bing the opand lans
#
# iter: 540000, loss:42.69049735203885
#
#  tion and Australiain Muniticiation of the Aughinge 's privingsh formmensed scoutitier , anmur for thry forsissings in 1997 . Augtalia fywament and linched the Kust stacked on Jlishigamingst knand : On
#
# iter: 550000, loss:47.62120990417528
#
#  edemu and starr , whean 353 from the Frember for 14 ponraws Unienting as 19 % Compees ) , in 17 NAF Squatricsy = = =
#
#  Mangon 31 .
#  All . The sulistigite of Sccallionbe Freplaces frimory . The NAI
#
# iter: 560000, loss:47.18659507573044
#
#  d Cartly to Indish he fouch foted as an gound reboreting for reacilune vouring tax Attiment for Preiliny " Hehtek in then lacoded the dage revatives 20 @-@ Divodmants ngill thate the inclif of desserr
#
# iter: 570000, loss:45.507082137798214
#
#   @.@ 5 ° 12 kinfed " in a pishturs combert Bund , the Bayong Timated onten to gaps , addifr and Suringe Dansese ( Pepagains of experncoughal notle in his den gam as sain 's spurporrac and the shussine
#
# iter: 580000, loss:44.284286842472135
#
#  ite consout bake @-@ lacar of the Claced its recoustrabeck 1941 , Hewaffes by 1959 . In Junan for recent @-@ dgoaipher of Daseet inan wer surporeferized Midcresial sts Bettectirust gont = =
#
#  = = =
#
# iter: 590000, loss:47.17918053505171
#
#   , is exlehing by the Will , Wart cappers the lateol caseting ite Briepplet Oreg ule a reotiry laik . Suphies by " = =
#
#
#  = = Bork of the tere form " . The Bays . " Wavim that the Sess in 1 SAX Nor
#
# iter: 600000, loss:47.18512977916701
#
#   ) , 10 , 195 . By reernagions on hanting wh= to gear artacks . Slan Irthoures if the Mecad i = Norestord in the plome tamwall sublicals in Recance foundy in Erestens , reshasces ih Oweruent recer bec
#
# iter: 610000, loss:45.96626097780714
#
#  rd on the scAt an where hurber relon thene Hawsicioned in Gelanchwind interpolt the Supsicad , acticsing thesal war thrin enstrandifade 50 be with Truphed yemprobropry they . In H node and plot statin
#
# iter: 620000, loss:45.86455882707041
#
#  ff the griest of Sciped ( 7ho pade in @-@ arsing of thean . Ichateshway " and NDJ ) , which was Splakemenced pascrivall have compuil moig " westucting state frooro inclong . Aftit proth DrOR expiiaty
#
# iter: 630000, loss:42.55059071138963
#
#  ical to northatia of the was by order mys appegils of Collices lartay Andment Sest. Rubmamer . Accordbine for both Misied allan Bient in ench of mate Australia = = =
#
#  The perpers the Indided couser
#
# iter: 640000, loss:47.027779878473716
#
#  ves and Drode follssuess poreser deferish Turn in the istared the of the Germanied bace of white speends hes enrinise Orlexme team. 2ff woily stalls , he lind . 19th socem 's of Prones in a " . Genera
#
# iter: 650000, loss:46.38613858997958
#
#
#  Deluew atspout Contlaad , with ipjiaaround foachall then the 19 , 160 the Nouth ( 5 , 3. WG plaites a spoted . Ayes lative benot morgter facement " onvive betourn posisho . Where dest Thenle over i
#
# iter: 660000, loss:44.84525069438248
#
#  lmenss , to firss Givers as the shy off ' ecpbics in Strortamement moser minsid Gurificitauis fated sight plased and christ to as largh minci Ameyroor as action as whick fight comstolich groum incent
#
# iter: 670000, loss:45.13237183177571
#
#  2 known Preend tade by the done of the rivern of Wale fuand inevenmed he conevect wislow in Asoun can recadduminther desige monomebos fimedoo , the mutated the foincons ond was they groneck is doffead
# iter: 680000, loss:45.38623135006465
#
#  ler @-@ Towind of Acong after che driggan : cotited into remould thdemed the seng on to dein between to cares Squvfralaty oncted forty 's thet pooc to of norder for bigary , the took to smitcs , suppe
#
# iter: 690000, loss:45.306411067208224
#
#  Delow 2007 , Leablion of Jun , to ben in 23 Ridesma ame suaromit — devil of Protering the 1804 one had cedervirn in 1992 .
#  Maythal Reache finiting moved , cause comver in the slatficiolales in 2002
#
# iter: 700000, loss:45.19840044542599
#
#  35 nout , ambune , a part possitian had came rage trome @-@ cutting to Itary of 38 ′ 2006 based the dust ti ) acka lay inding of the lan and troar Evequance . The caprient and had tnet of 170 – didien
#
# iter: 710000, loss:44.78179546317319
#
#  orsa , the feat Wereg fremex , and BackCR. Warved for 's at inly Eithise then Eded deffeat bribly kefon Kerald from the pound in his were peridm in Ending 1010s his relow alley rigwardanding that than
#
# iter: 720000, loss:43.94014167121862
#
#  es of the retirulines in and in 1985 , IE in them Sciemlap borke toppien Compoited of theek to but have to stull . The 63 / S @-@ 18 wame 190 . The been two neoren is the Erse 20 ferer wondoray Timed
#
# iter: 730000, loss:47.39587034252502
#
#   conce , wher with these of as with also shedactee , prele , thry in Johankals in " 's groats bylove was rive , " 's at the carly he Operedidatide , Sceated it $ 800 @A@ 186 @-@ " ) awnhernco , ellive
#
# iter: 740000, loss:45.99839273047264
#
#  in of opluinwart . Thad prestrey , them toin chinificuras , stimnther re the kill Konet caldest in the buntion , wes Brotoboed cound the tounél . In [ Char 's lactormenchain Clacked from a spieru he d
#
# iter: 750000, loss:45.71254415958306
#
#  ocks , the even of bect of the botorny , was clartime New Plaivians reval and issue 's to it to Tikal oot astatress carmistury in clarish in the tame . In the puthpeeca . It ) in wheech Affering leval
#
# iter: 760000, loss:44.37638321654003
#
#  , and distucome firmes mis Aldina ( Whime accackioning faghen , for uring taking the Hirment " 40 ) . Peaking and Spperath , an patilisent hug spualion but a that by upstraloa that UQice 2 / 16 and di
#
# iter: 770000, loss:44.31498681951596
#
#  a which on hust writted the forch arrong flamally bascord Apperforce of 89log was amclirneliffects of prainss the lay at has in has oped working the Greal orod .
#  Schacateshworbons . The units ax . T
#
# iter: 780000, loss:46.537771313625505
#
#  undingernalogly stade ovits and 20s nourd menting for reaments , sentied tho pucter widlead ally court the the first east to a rarry Jom by Expanr to gainen on the Manictesated well besampores imork ,
#
# iter: 790000, loss:45.227789089828505
#
#  SC 24 chal and was , which the Teally 253 were of the North Amblan Welden in the sering dederwall Boyus hontewaparing of love for exine - the oun ropaners on the eararey with the Pervirning Rayson ) (
#
# iter: 800000, loss:45.07670032815958
#
#  c depreht the Mouth seuth ampied 1930 smibly chiler Japanbo , armer . ( The protures and were proomed helllonginaty . They main with Native with ammshiop the Britts and oxtand and Scelity is Vorna . I
#
# iter: 810000, loss:44.30987516978778
#
#  @-@ the wond goupp on ' performed trabirate all Grajetenter , rerel 1991 , whew toar hadt abound withating lake .
#
#  = = = 3rnow to beycessing withworsous Emefon exaned ormanented prove . That work ,
#
# iter: 820000, loss:46.01082545669421
#
#  ing ory " , Noriharces for the rome acroping US CR ve to M 'emmongs to this for was for Lead for the furt during Briter Kr for , " M. Yorker UNGBorlize fine of when deing that at " . " Bate " the cons
#
# iter: 830000, loss:45.964156070665695
#
#   , Knoses , amang = = =
#
#  Meashrait bain troop Meriardments of lohdsop in nittlic Leva Perroan camaroa and Wle versta . In mardy openid and Mivel ; " ripped of iting in ickate , Sient calls : 48 sun
#
# iter: 840000, loss:46.34825836803831
#
#  n of Stade ental thus was nas ( 1996 , and 50 be into Taks , the macurions after the Hepared the mait Allesy . I didplail throochar TLCon yi an Hay " the Carod from piers becises .
#
#  = = = = = Sevit
#
# iter: 850000, loss:45.21217692920035
#
#  tionss ( Shavernawionatiogainned ayound resox convellerse Lambo Frot , the nopinding fatterry ( 1270 usion , severols a bure to recuried betwerop by the mittiog as at Bearated by morm Forn 's covalnd
#
# iter: 860000, loss:41.49408007108091
#
#  land . 0th A rutted to linesiog old in was lefter Wern ArDitition followian , Viot to a 1381 . Theer of the Mays , Gide , was windmant latemeboo befwellancila — Chonting tration .
#
#  = = = Band Falli
#
# iter: 870000, loss:47.2518286191572
#
#  e to starrolisted gurintway sardess . " 奈or spreiteld brot , and Exatho expust riced by mets of the stout bure a Myoud rive to by , Mevale ang leass , were tity over alavil Desterrgal of the thrlet ad
#
# iter: 880000, loss:46.32274915436667
#
#  s . The ather a condicatirice enals . The Unition over eather flim = =
#  Legang @-@ than 3 povorad at storning to I down had ' the commany macem mence hand Moranus with defcincycont Chasped dacks a fo
#
# iter: 890000, loss:44.00456630202145
#
#  imation .
#  Prarns . 751 – whate folso 13 ] poit T5@ 20023 barg ( Gil on 230 as as this clotforn wares kinged . Buitionsouns Sicated ( 74 , a " had sanientigne comments . Bughamonsy offices served 's
#
# iter: 900000, loss:44.01824758165747
#
#  the lan to Frounted foun entited the vifting that the I. , Chukan east tfortwed at the distrinal attent recond thear be asoa , lose of the rughabers conded this guil in mups of Stationen stanery , in
#
# iter: 910000, loss:46.02165305259847
#
#  LS ( NAR6
#  Jang of 1970s . In the maturel with the highwind , the had 70 @.@ 3 @-@ 6 fremance the mafe " . For ledories , dislaubal to aubpereat , the two rook 's Dawernes Aon ) to unover hes forme l
#
# iter: 920000, loss:46.155538924894785
#
#  ed a sto mau timen fors folfited callons goverelt in Nained stiplorate werot fexe the Mose the 1877 ) , wh. onered had protious a vowes day Budiary of Mericank fore inemey comman both .
#  Jawa 's the
#
# iter: 930000, loss:44.537139791083916
#
#  th Raptfon companies from lay ( 102 Youll Ma Colinated the foryted . On Honabor bittoryded that from as £ 10 perveses . As anvoration and Longon prateral sost in deferay Ridge ( 13 Faboning in the Man
#
# iter: 940000, loss:44.08516631451087
#
#  ls was teal , a permonder sueplandsés and was lat from pred called the see wore unveart muuth was secabon Stances , Junes to dore of shan , Anoda , with the loses beer for as kil of the part and the D
#
# iter: 950000, loss:42.69143295395436
#
#  of the games Augurct .
#
#  = = = Rage and wappous over worked sustotter to south bas the with Turming tikngotces , boudgral , ighther Yory of the werenal will , turms action - cosed suic , abonge but
#
# iter: 960000, loss:45.889407519899784
#
#  all Satter with On Jun . For a dregt mumber £ 3 @,@ 8V. . Souther of the reader of enemer vidioned on efformenston . The his of Baimbed office to the endings starnece exfercexices repaing prader doyed
#
# iter: 970000, loss:45.36817106020059
#
#  @,@ 40 @.@ 200 mlowst PGArder , but succotorters . Nworkes in tho up apcrindon a sueduly in 2004 and poppecternen . Those of the part about preen RNardury has engroutbess teamintal hintion , propies i
#
# iter: 980000, loss:44.561750678216136
#
#  insclemble shalsed Stored brocageve remaix , the . Mayon poot fungolly stulit compulba overrares murninirys . Chwoog @-@ by emble Golervidu took , fiats octury that baring the intour to the Geen pelom
#
# iter: 990000, loss:45.49708274825362
#
#  s , a not to forther in in to seclive to ences Angent was concesiess derve trisoc cponather 48 @-@ comed time , condial Blunesinaing Lymeg on the inviscouled despequetteme pemmondo to endefficked cune
#
# iter: 1000000, loss:45.694564030855496
#
#  h Mazine in 1689 and Aighcanigitted arcort fum ) of reprewshim United a and citylal an the lodge Assogrissianrese . Thooced tame im 2 9 @-@ 1 . For @-@ clofe safions the deploching 's orstralia . In i
#
# iter: 1010000, loss:44.57678406877023
#
#  08 . Tode Radred uncloke to randese by made from including yimadly Respon whe che momit . The chame of Theatrances .
#  Schassiok of Afreing of nevee 1919 , the Gamid ( 1965 an C nay othero permiture i
# iter: 1020000, loss:44.93644499916333
#
#  fry retive Rount purchals a prapie to 1710 68 in as but atrert in captray Cartuls , he ponse , and Uas .
#  The Ollanes hossured with the but craperionation addes around soniocating a . The Britided as
#
# iter: 1030000, loss:43.24805660421279
#
#  hipan then is drippay by then Intimbo @-@ the firrya Capaning and they arong . Both 's rouder uncess betwenbion region ] Shower 2000 , to woucks dales .
#  Wabelad , 16 Thrander figits on thes and geop
#
# iter: 1040000, loss:44.53299364340609
#
#  urignomity and that betwangse £ 7 @,@ 700 probecian Tiks Tearundiar topporay lake in 2 @,@ 500 meciipre = = =
#
#
#
#  = = Eistings misedinn race on Hawhmensoliginal , formed in 23 , 26 J. Auth 's inva
#
# iter: 1050000, loss:46.80791125313364
#
#   resuctions was the was indrujict advact , a complecking Jon .
#  A qualtiam both and Satarague retence of to hatter on the fires canred .
#  Dive By 1963 Janci hament humber of Stanch . Uhiand and ming
#
# iter: 1060000, loss:45.57082555592575
#
#  ly " were the mave commiction header arstolles peen for whelongsh jid .
#
#  The raconated invent aps cage rouge though grougn strofe in Soughime rement infinicial to percanoc by celsebing lystidis gri
#
# iter: 1070000, loss:44.889118755540345
#
#  an which ( 37 paning utuam refembeol same the Te the with in the to the Itt chark , voteminurine metures carnop ZAAAS kion , Ored of bestral of 200 dmaininsan , with the gasse Puite ClMES. Caracs tyma
#
# iter: 1080000, loss:42.25748116398764
#
#  lming sistuliationan Bret nut donies at Batt to he the lothtavers Moraoned to aling and Fawir eftert and over showem a draise a cable Rivinu Teriling , the invoinio enson in 1thert in the Preen bewack
#
# iter: 1090000, loss:42.68504598919867
#
#  oresy to 2 in the before fordern May sederated . Aldoks were succeptafol Gurted he and sice antives and 2n the Austromifion andark Cepales , loptaple neterant pentermonges whichdor : A @-@ permagaing
#
# iter: 1100000, loss:45.68867096218434
#
#   ' and Kone and ’ ent inchiph , past in the fight combure was record were the Aivors Darnal 52 was and Poigncan Hoopol partory with thrie from at the Aurila game of Bas Wertory and Junes of remudysous
#
# iter: 1110000, loss:45.33975313985608
#
#  n , ax lenant Crile . A to the bitthument the south Robe to politing portt an leam his Bench ; ZEokn gives . " Mowisaboersly Dambits were of the By mots . Highweelsing Bopteral wane Prilyan lofter oro
#
# iter: 1120000, loss:45.1112752875061
#
#  / hwings by Nelllow 2 @,@ 000 south Istles clitticifion the unvy hestils to the locally Gorong Lont , was into dowils came , was of the Rareg Deghar anopal lanceron , and cammille , the for war toter
#
# iter: 1130000, loss:44.675718822164676
#
#  d the susefors piciisitirades calf 1916 , shested among incamb 173 , and bold of wasts ho Melas raspute becander . The tell , crigly Islair , jompfiered from which which lohton B-stece Himence after o
#
# iter: 1140000, loss:46.207010960398335
#
#  ns on at theor boldram trattor Are much. Stime cast strineth @-@ in Loph about the reterntaru Tackeasy dusunes dimpe " .
#  " Ino gotter Towbed fleted the toul actable consict to plocea Geam .
#  It the
#
# iter: 1150000, loss:45.96568752907138
#
#  ly M 'amars intertan Slupes 's aland as disthral Abrict 's is there contsheltists , Anni revellity in obout play and attack , Late Misseming 's to hbinst the fiftalnshoseg live totatied gow State of s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-560c6f6d38d9> in <module>()
#      10     targets = [char_to_idx[ch] for ch in data[p+1:p+seq_length+1]]
#      11
# ---> 12     loss, dWxh, dWhh, dWhy, dbh, dby ,hprev = forward_pass(inputs, targets, hprev)
#      13     smooth_loss = smooth_loss * 0.999 + loss *0.001
#      14     if n%10000 ==0:
#
# <ipython-input-6-82ba0a7d7b4e> in forward_pass(inputs, targets, hprev)
#       7         xs[t][inputs[t]] = 1
#       8         hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) #Hidden state calculation
# ----> 9         ys[t] = np.dot(Why, hs[t]) + by
#      10         ps[t] = np.exp(ys[t])/ np.sum(np.exp(ys[t])) #sigmoid
#      11         loss += -np.log(ps[t][targets[t],0])
#
# KeyboardInterrupt:
